# %%
import numpy as np
import scipy.fftpack as fftpack
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
# %matplotlib inline

from astropy.table import Table
from astropy.time import Time

# %%
# %qtconsole

# %%
data_file = '/home/equant/classes/lsstdsfp/data/session_9/thingspeak.csv'

csv_data = Table.read(data_file)

csv_data['timestamp'] = [x[:-4] for x in csv_data['created_at']]
csv_data['time'] = Time(csv_data['timestamp'])

# %%
plt.plot(csv_data['time'][0:10], csv_data['field2'][0:10])
# Out:
# ----------------------------------
# ValueErrorTraceback (most recent call last)
# <ipython-input-31-ebed9f0e546e> in <module>
# ----> 1 plt.plot(csv_data['time'][0:10], csv_data['field2'][0:10])
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
#    2748     return gca().plot(
# -> 2749         *args, scalex=scalex, scaley=scaley, data=data, **kwargs)
#    2750
#    2751 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...
